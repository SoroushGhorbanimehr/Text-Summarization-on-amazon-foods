# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_csv("../input/amazon-fine-food-reviews/Reviews.csv",nrows=100000)[:2000]

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1996 entries, 0 to 1999
# Data columns (total 10 columns):
# Id                        1996 non-null int64
# ProductId                 1996 non-null object
# UserId                    1996 non-null object
# ProfileName               1996 non-null object
# HelpfulnessNumerator      1996 non-null int64
# HelpfulnessDenominator    1996 non-null int64
# Score                     1996 non-null int64
# Time                      1996 non-null int64
# Summary                   1996 non-null object
# Text                      1996 non-null object
# dtypes: int64(5), object(5)
# memory usage: 171.5+ KB

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))

# %%
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9468138484696438

# %%
max_text_len=50
max_summary_len=10

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
df['summary']
# Out:
# 0                sostok good quality dog food eostok
# 1                    sostok not as advertised eostok
# 2                  sostok delight says it all eostok
# 3                       sostok cough medicine eostok
# 4                          sostok great taffy eostok
#                             ...
# 1607              sostok delicious but pricey eostok
# 1608    sostok great waffles for us non cooks eostok
# 1609                    sostok good basic mix eostok
# 1610        sostok good pancakes lots of work eostok
# 1611                sostok waffles schmaffles eostok
# Name: summary, Length: 1612, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),
                                       test_size=0.1,random_state=0,shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 71.30892091936111
# Total Coverage of rare words: 15.293423768799762

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 88.60465116279069
# Total Coverage of rare words: 22.939386254121228

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (1450, 1450)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
import tensorflow.keras.backend as K
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 100)      147400      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    14800       input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 148)    88948       concat_layer[0][0]
# ==================================================================================================
# Total params: 2,836,248
# Trainable params: 2,836,248
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=5,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Train on 1279 samples, validate on 145 samples
# Epoch 1/5
# 1279/1279 [==============================] - 14s 11ms/sample - loss: 1.3639 - accuracy: 0.7395 - val_loss: 1.3445 - val_accuracy: 0.7418
# Epoch 2/5
# 1279/1279 [==============================] - 3s 2ms/sample - loss: 1.2969 - accuracy: 0.7409 - val_loss: 1.3400 - val_accuracy: 0.7425
# Epoch 3/5
# 1279/1279 [==============================] - 3s 2ms/sample - loss: 1.2738 - accuracy: 0.7419 - val_loss: 1.3451 - val_accuracy: 0.7387
# Epoch 4/5
# 1279/1279 [==============================] - 3s 2ms/sample - loss: 1.2742 - accuracy: 0.7416 - val_loss: 1.3519 - val_accuracy: 0.7349
# Epoch 00004: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: looking blend longer carried amazon coffee green mountain nice strong enough like coffees one
# Original summary: good coffee
# Predicted summary:  great
#
#
# Review: low carb diet lost pounds tired eating meat time pasta came across product amazon cook minute two longer top full fat yogurt cheese one serving filling yummy definitely cravings subscribe save hubby son love
# Original summary: fantastic
# Predicted summary:  great
#
#
# Review: extract ingredient right chips contain extract chemical level different kettle still products msg chips safe people msg
# Original summary: the organic is
# Predicted summary:  great for
#
#
# Review: tasty chips ones salt flavor way salty sure likes much salt chips
# Original summary: too salty
# Predicted summary:  great for
#
#
# Review: really like product tasted great took minutes make microwave
# Original summary: tasty and easy to make
# Predicted summary:  not not the
#
#
# Review: purchased oz bag realize ounces compared bags might perfect us bag potato chips cut might perfect kids
# Original summary: chips in the
# Predicted summary:  great
#
#
# Review: read try made anything yet eaten little bit time wow dark sour little sweet dessert really unique flavor yum going try making next
# Original summary: this stuff is good
# Predicted summary:  great for
#
#
# Review: miss better unfortunately less available sure tough right difference two brands miss better
# Original summary: ok but are better
# Predicted summary:  not not my
#
#
# Review: idea good caramel flavors ginger chocolate orange honey varieties mix rich flavor sugar expect caramels
# Original summary: not for
# Predicted summary:  great
#
#
# Review: favorite chips bbq salt pepper best texture things rock nicely packaged gluten free care
# Original summary: love these chips
# Predicted summary:  great
#
#
# Review: yes cup right went town looking coffee non delicious food top amazing delicious coffee paid extra bucks get right way worth money highly recommend
# Original summary: this is excellent coffee
# Predicted summary:  great for
#
#
# Review: flavors tic tacs favorite great cherry flavor love bad available purchase locally
# Original summary: yummy
# Predicted summary:  great
#
#
# Review: great taffy great price assortment yummy taffy delivery quick taffy lover deal
# Original summary: great
# Predicted summary:  great
#
#
# Review: good frozen lemon juice good slightly odd flavor perhaps sure wish could order frozen juice
# Original summary: juice
# Predicted summary:  great
#
#
# Review: fantastic chips ever could eat whole bag made lots whole grain beans make complete protein feeding kids snacks great problem bag small need bigger bag
# Original summary: so good
# Predicted summary:  not good
#
#
# Review: stuff rocks two different love tart really real treat
# Original summary: good
# Predicted summary:  great
#
#
# Review: use lot raw cocoa power protein drinks high price cocoa market excellent price especially organic product cocoa less tasty regular brand well price main complaint product came sealed plastic bag label would like see organic label well nutrition product
# Original summary: the price is right
# Predicted summary:  not to
#
#
# Review: mother father wonderful pieces chocolate heaven believe receiving know deserve receive
# Original summary: chocolate
# Predicted summary:  great
#
#
# Review: baby loved one cut one runny spoon quickly way hands think could use little less water maybe little potato make consistency turkey dinner one
# Original summary: good flavor too
# Predicted summary:  not good
#
#
# Review: spicy version ketchup bad expensive regular version sweet dessert horrible organic much better flavor costs lot less even organic better deal gave three stars instead two glass plastic
# Original summary: disappointing
# Predicted summary:  great
#
#
# Review: super would definitely recommend reason giving stars wish bigger
# Original summary: yum
# Predicted summary:  great
#
#
# Review: would even think buying product know price per unit compare items online store
# Original summary: what is it
# Predicted summary:  not is
#
#
# Review: seemed like perfect way limit potato chips small single serving bags really like plain popchips rest flavors aftertaste plan set subscribe save plain
# Original summary: only like the
# Predicted summary:  great
#
#
# Review: item got house time surprised well package packed recommend store anyone
# Original summary: was good
# Predicted summary:  great
#
#
# Review: purchase making per unit price even lower list said pop chips tasty variety pack comes different flavors favorite flavors salt vinegar far calorie count makes snack guilt free
# Original summary: just my
# Predicted summary:  great for
#
#
# Review: else need know oatmeal instant expensive store brand oatmeal maybe little tastier better texture something still oatmeal mm convenient
# Original summary: it is
# Predicted summary:  not is
#
#
# Review: weight watchers chips points taste great like every kind use plain chips dip salsa would chips everyone weight watchers
# Original summary: great chips
# Predicted summary:  great
#
#
# Review: pop chips great heard really good totally agree love able flavors like variety chips delivered quickly
# Original summary: love chips
# Predicted summary:  great
#
#
# Review: heard chips thought would good alternative regular chips could eat though taste good personally loved though gave rest
# Original summary: not like the taste
# Predicted summary:  not is the
#
#
# Review: love love love year old drink herbal tea quite often tasty
# Original summary: delicious
# Predicted summary:  great
#
#
# Review: first drink mother brought back home thought delicious wish bit cheaper love product
# Original summary: delicious
# Predicted summary:  great
#
#
# Review: love pop chips variety bag great deal especially tasty low fat needed healthy alternative great price highly recommend
# Original summary: excellent
# Predicted summary:  great
#
#
# Review: son daughter law told chips purchased bags store say higher stores get online amazon brought bag hooked ordered popchips online best chips flavor like family like better great tasting chip highly recommend anyone cannot without eating chips either sandwich munch dissapointed
# Original summary: best chips
# Predicted summary:  great
#
#
# Review: products wonderful fresh everything chips target would recommend others amazon fantastic
# Original summary: pop chips
# Predicted summary:  great
#
#
# Review: cat go day probably longer right stuff every time even know absolutely would rather even take
# Original summary: cat will not it
# Predicted summary:  not not my my
#
#
# Review: tasty chips healthier alternative regular chips without flavor fact taste better regular chips would highly recommend product choose favorites sea salt vinegar followed salt pepper original flavor least favorite probably spoiled flavor others offer
# Original summary: loved it
# Predicted summary:  great
#
#
# Review: bought folks prepare must say absolute best item ever tasted make tastes like heaven highly recommend everything tend apples dip tried toast well
# Original summary: absolutely the best
# Predicted summary:  great
#
#
# Review: soy sauce best ever thanks amazon able find makes big difference using product thanks
# Original summary: best sauce ever
# Predicted summary:  great
#
#
# Review: best salt vinegar chips ever salt right vinegar perfectly chips good salt pepper little overwhelming
# Original summary: and sweet
# Predicted summary:  great
#
#
# Review: best way buy beer nuts perhaps product high heat whole lot coating flavoring nuts even though individual cans sealed like nuts sitting bowl long time hot day
# Original summary: not my best
# Predicted summary:  not my my my
#
#
# Review: first bought asparagus market love first bite saw local even better ones market fantastic jars garlic bottom going order six pack one wont go waste
# Original summary: vinegar on is
# Predicted summary:  great
#
#
# Review: like eating large box paste enjoy flavor usually cook mix something else eating go straight box
# Original summary: good flavor but
# Predicted summary:  great for
#
#
# Review: friend favorite candy available anywhere area could find line either amazon com came england delicious thin smooth mint cream center dark chocolate want little taste mint really special cup hot coffee
# Original summary: to find
# Predicted summary:  great for
#
#
# Review: sure guy like much love fact might one favorite foods around tried true rarely wrong always good warm flavor good tried brands bit makes best ramen noodles time
# Original summary: the best
# Predicted summary:  great
#
#
# Review: hard find wintergreen sugar free stores red common flavor wintergreen refreshing absolutely delicious country someone turn daughter hand say wintergreen one hand right world
# Original summary: me
# Predicted summary:  great
#
#
# Review: done side side comparison chips still taste like real deal snack sized bags well regular brand grocery store work portion control reduced fat yes please subscribe save much cheaper grocery store
# Original summary: delicious
# Predicted summary:  great
#
#
# Review: found chips see little fat taste great actually bad either told sister told friend everyone loves try order boxes work instead using office loves little hard find order online
# Original summary: pop chips are great
# Predicted summary:  great
#
#
# Review: favorite home like ones sea salt also like barbeque flavored chips cut plain potatoes thick crunchy great texture mouth also great taste sea salt ones favorite enough salt salt much feel like drink gallon water chips enjoy
# Original summary: love kettle chips
# Predicted summary:  great
#
#
# Review: jerky processed hard like rock greasy stale something cannot break anything smaller long certainly size training treat dogs lb dogs eat anything impressed hard chew like rocks left would first time would eat something entire lives dogs work star
# Original summary: awful
# Predicted summary:  not to
#
#
# Review: product works great hate money herbs use little rest go bad put herbs fresh weeks either bottom clearly lock stays thing already paid money saved looks pretty cool fridge ready cook
# Original summary: for me and me
# Predicted summary:  not is the
#
#
# Review: bought chips reading good reviews disappointed taste nothing like expected bought flavor variety pack many flavors care worth trying going purchase future
# Original summary: not so great
# Predicted summary:  not not my
#
#
# Review: love stevia tried many different kinds years one goes great coffee tea one ship get one month
# Original summary: great product
# Predicted summary:  great
#
#
# Review: dinner friends family awesome fabulous food serve china tea time organic green doubt best flavored tea ever
# Original summary: best tea ever had
# Predicted summary:  great for
#
#
# Review: good omaha food sent already left one
# Original summary: and
# Predicted summary:  great
#
#
# Review: husband twizzlers addict bought many times amazon living cannot get country always fresh tasty packed well timely
# Original summary: fresh
# Predicted summary:  great
#
#
# Review: nuts arrived fresh tasty broken dirty looking like sometimes
# Original summary: fresh and tasty
# Predicted summary:  great
#
#
# Review: popchips great alternative need snack much lower calories fat regular chips especially like barbeque flavor salt pepper flavored popchips
# Original summary: popchips
# Predicted summary:  great
#
#
# Review: far favorite chips extremely crunchy vinegar flavor fried potato snacks tried several brands salt vinegar none come close
# Original summary: my favorite chips
# Predicted summary:  good
#
#
# Review: hot love tasty little sweet usually salsas hot one lives
# Original summary: hot
# Predicted summary:  great
#
#
# Review: one son favorite baby foods bit sweetness sweet runny flavors use spoon one add little rice cereal
# Original summary: one of our
# Predicted summary:  great for
#
#
# Review: one thing dog likes liver biscotti dog treats make best training treats used
# Original summary: make your dog happy
# Predicted summary:  not not my my
#
#
# Review: best seasoning salt dish spicy perfectly seasoned perfect purchase oz
# Original summary: the of all
# Predicted summary:  great
#
#
# Review: recently started using bob red baking soda pleased sure thanks bob
# Original summary: this is the
# Predicted summary:  great for
#
#
# Review: along omaha prime great two plenty fill made oven less minutes
# Original summary: quick easy taste great
# Predicted summary:  not not the
#
#
# Review: best eats one little thicker original chicken sweet potato favorite runny
# Original summary: baby this one
# Predicted summary:  great for
#
#
# Review: boxes cherry great buy could find cherry store really care flavors
# Original summary: all could not find it in
# Predicted summary:  not not my
#
#
# Review: hard get husband eat breakfast school takes two bars happy often hard find flavor local grocery stores amazon com came reasonable price came keep husband breakfast ready door often like bar night snack
# Original summary: favorite
# Predicted summary:  great
#
#
# Review: love eating good watching looking sweet like zip lock stay fresh take time eating
# Original summary: taste
# Predicted summary:  great
#
#
# Review: great tasting one best ever problem high shipping costs
# Original summary: great taste
# Predicted summary:  great
#
#
# Review: one best tasting ever eaten buy special know eat whole bag
# Original summary: excellent taste
# Predicted summary:  great
#
#
# Review: told future herb vegetable salad inside grow vegetables thought herb savor looked like perfect wrong bottom comes loose water everywhere plastic back hold good idea nice looking product poorly purchasing plastic bags much much better
# Original summary: disappointing
# Predicted summary:  great
#
#
# Review: excellent cereal top use ramen noodle hot sour soup well good almost peanut flavor much salt lightly seasoned must try anyone low calorie addition diet even dog loves thinks special treat
# Original summary: like
# Predicted summary:  great
#
#
# Review: favorite gluten free free flavored chips many salt vinegar chips contain nice find ones eat vinegar flavor really intense good
# Original summary: best gluten free free chips
# Predicted summary:  not not my
#
#
# Review: bought coffee much cheaper organic well healthy expect taste good actually days totally worth take less expensive similar coffee product weeks
# Original summary: not bad for healthy coffee
# Predicted summary:  not not the
#
#
# Review: found recent trip england find soon got home standard us around forever use many cakes fresh fruit whipped cream even french toast
# Original summary: delicious best ever
# Predicted summary:  great
#
#
# Review: chips pretty delicious even original flavor nothing good delicious also fried either definitely good snack times day
# Original summary: pretty delicious
# Predicted summary:  great
#
#
# Review: purchased locally many flavors ordered blueberry online try available locally love blueberry well disappointment sugary sweet little blueberry flavor mention paid would pay locally disappointed
# Original summary: sugar free
# Predicted summary:  great
#
#
# Review: chips good fast service ordered case popchips flavor variety pack received bags barbecue flavored
# Original summary: good but not what was
# Predicted summary:  great
#
#
# Review: found product kettle chips unsalted fabulous found amazon local stores crisp tasty without salt
# Original summary: kettle chips
# Predicted summary:  great
#
#
# Review: whole box peanut butter dog cookies wont touch loves good buy little big mouth per box
# Original summary: loves them
# Predicted summary:  great
#
#
# Review: son multiple food allergies really enjoys bars find good berry taste also nice
# Original summary: good flavor
# Predicted summary:  great
#
#
# Review: terrible artificial lemon taste like lemon use plain salt fresh lemon
# Original summary: taste
# Predicted summary:  great
#
#
# Review: finally found natural sugar substitute added low agave delicious recommended many friends economical purchase oz bottles
# Original summary: sugar
# Predicted summary:  great
#
#
# Review: first time muffin mix well baking muffins muffins came little dry tasted great people shared said good purchase white muffin mix future muffin mix came excellent price cannot complain thank amazon com everything sale
# Original summary: chocolate chocolate chip mix
# Predicted summary:  not my my my
#
#
# Review: low orange reading reviews decided try almost good orange still favorite cherry pretty close
# Original summary: good
# Predicted summary:  great
#
#
# Review: love kettle brand chips love honey years decided try flavors sea salt vinegar chips tangy sour make lips eat many time got big bags amazon personally flavor much mom love hate potato chips
# Original summary: up
# Predicted summary:  great
#
#
# Review: almost pops less cents great children trip
# Original summary: could no to pop
# Predicted summary:  great for
#
#
# Review: love jalapeno chips kettle must try nice kick jalapeno delicious addicting recommended
# Original summary: crunchy and spicy
# Predicted summary:  great for
#
#
# Review: love flour however amazon sent book bag made mess customer took care problem however way ship product
# Original summary: love the product in the
# Predicted summary:  great
#
#
# Review: best potato chips money buy enough salt taste much bag chip perfect teeth get excited every time put one mouth everything chips perfect like made god delivered know amazon carries even leave house buy may never eat anything else
# Original summary: delicious
# Predicted summary:  great
#
#
# Review: fresh food okay product kind like food daughter interested little lost may back see
# Original summary: was not that
# Predicted summary:  not not the
#
#
# Review: happened upon item local decided try fabulous better regular chips far gives satisfaction crunch flavor potatoe chip great great find
# Original summary: great crunch
# Predicted summary:  great
#
#
# Review: ordered dad day ate whole box within two days said tasted really good want order
# Original summary: really these
# Predicted summary:  great
#
#
# Review: perfect size sea salt table basket love well
# Original summary: great tasting salt with
# Predicted summary:  great
#
#
# Review: tried sampler packs great way get exactly brands style want received order couple days exactly ordered second order ordering item
# Original summary: best way to buy
# Predicted summary:  great for
#
#
# Review: england custard like vanilla custard pudding love rich creamy lots vanilla taste love comes big make much want would never make anything else
# Original summary: best ever
# Predicted summary:  great
#
#
# Review: great fan potato chips thai food happy kettle chips decided two great loves together chips spicy enough without burning hole tongue also nice hint sweetness makes habit treat definitely worth
# Original summary: great new flavor
# Predicted summary:  great
#
#
# Review: simply fell love chips share friends experience lot cheese chips salty little greasy side cheddar kettle really changed mind thanks amazon great buy store anymore
# Original summary: excellent of taste and
# Predicted summary:  great
#
#
# Review: originally found target home town fell love part weight watcher plan good snack alternative something salty could find live purchased pop chips web site took amazon yummy
# Original summary: yummy
# Predicted summary:  great
#
#
# Review: used recipes syrup mixed orange water wonderful wonderful stuff
# Original summary: best stuff ever
# Predicted summary:  great

# %%
model.save("text_summarization_model.h5")
